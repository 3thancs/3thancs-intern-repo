# %%
# 1. Magic Numbers & Strings
def calculate_total(price):
    # What is 1.08? What is 5?
    return (price * 1.08) + 5

# %%
# 2. Long Functions
def process_user_data(user):
    # Validation
    if not user.email or "@" not in user.email:
        raise ValueError("Invalid email")
    
    # Database logic
    conn = database.connect()
    conn.execute(f"INSERT INTO users VALUES ({user.name}, {user.email})")
    
    # Notification logic
    server = smtplib.SMTP('smtp.example.com')
    server.sendmail("admin@site.com", user.email, "Welcome!")

# %%
#3. Duplicate Code
def get_admin_emails():
    # Logic to format email list
    users = db.get_admins()
    return [u.email.strip().lower() for u in users]

def get_customer_emails():
    # Same logic copied!
    users = db.get_customers()
    return [u.email.strip().lower() for u in users]

# %%
# 4. Large Classes (God Objects)
class SmartHomeSystem:
    def adjust_thermostat(self, temp): ...
    def play_music(self, track): ...
    def calculate_monthly_energy_bill(self): ...
    def update_security_firewall(self): ...
    def cook_popcorn_in_microwave(self): ...

# %%
# 5. Deeply Nested Conditionals
def get_payout(user):
    if user.is_active:
        if user.has_balance:
            if not user.is_blocked:
                return user.balance
            else:
                return 0
        else:
            return 0
    else:
        return 0

# %%
# 6. Commented-Out Code
def apply_discount(price):
    # new_price = price * 0.9  <-- Why is this here?
    # if user_type == 'PRO': 
    #     return price * 0.8
    return price - 5

# %%
# 7. Inconsistent Naming
def total(lst, x):
    # What is 'lst'? What is 'x'?
    for i in lst:
        i.val = i.val + x
